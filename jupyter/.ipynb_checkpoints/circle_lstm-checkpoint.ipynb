# %%
# add modules to Python's search path
import os, sys
from pathlib import Path
nb_path = Path(os.path.abspath(''))
sys.path.insert(0, str(nb_path.parent) + r'\python')

# %%
# import modules
import tensorflow as tf
import numpy as np
from modules import nnplot as nnp
from modules import integrate as quad
from modules import lstm

# %%
# set experiment parameters
D = 0.51
R = 6.0
T = 10.0
alpha = 0.3
beta = 3.0
gamma = 1.0
space_r = np.array([0.0, R])
space_theta = np.array([-np.pi, np.pi])
space_x = gamma * R * np.array([-1., 1.])
space_y = gamma * R * np.array([-1., 1.])
time_ = np.array([0.0, T])
num_nodes = 50
num_layers = 3
nn_type = 'LSTMForget'
model_name = 'cricle_lstm_{}_{}_{}_{}'.format(num_nodes, num_layers, nn_type, str(D).replace('.', '_'))

# %%
# define f
f = lstm.LSTMForget(name=model_name, num_nodes=num_nodes, num_layers = num_layers, data_path='..\data',\
                    dtype=tf.float32, final_activation=tf.square)

# %%
# define differential operator
#@ut.timer
def diff_op(t, r):
    r2 = r*r
    z = 4.0*(r2 - 1.0)
    #t = t[0]* tf.ones_like(r)
    with tf.GradientTape() as outer_r:
        outer_r.watch(r)
        with tf.GradientTape() as inner:
            inner.watch([t, r])
            f_ = f(t, r)
        grad_f = inner.gradient(f_, [t, r])
        f_t = grad_f[0]
        f_r = grad_f[1]
    f_rr = outer_r.gradient(f_r, r)
    b = f_r
    a = (D + z*r2) * b
    c = 4.0*r*(z + 2.0)
    eqn = - r*f_t + a - c + D * r * (f_rr - b**2)
    return tf.reduce_mean(eqn**2)

# %%
# add as an objective
f.add_objective(diff_op)
f.add_domain(time_, 'uniform', space_r, 'uniform')

# %%
# define initial condition
log_4_R2 = tf.cast(2.0 * tf.math.log(2.0 * R), f.dtype)
init_cond = lambda r: 10.0*tf.reduce_mean((f(tf.zeros_like(r), r) - 0.5*r*r)**2)
print(f(*f.domains[0].sample(5)))
f.summary()
# Out:
# tf.Tensor(
# [[0.062341  ]
#  [0.00262719]
#  [0.00889485]
#  [0.00772339]
#  [0.00184674]], shape=(5, 1), dtype=float32)
# Model: "cricle_lstm_50_3_LSTMForget_0_51"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTMForgetBlock (LSTMForgetB multiple                  1000
# _________________________________________________________________
# LSTMForgetBlock (LSTMForgetB multiple                  10600
# _________________________________________________________________
# LSTMForgetBlock (LSTMForgetB multiple                  10600
# _________________________________________________________________
# final (Dense)                multiple                  51
# _________________________________________________________________
# batch_normalization_1 (Batch multiple                  200
# =================================================================
# Total params: 22,451
# Trainable params: 22,351
# Non-trainable params: 100
# _________________________________________________________________

# %%
# add as an objective
f.add_objective(init_cond)
f.add_domain(space_r, 'uniform')

# %%
# define boundary condition
def bdry_cond(t):
    r = R*tf.ones_like(t)
    with tf.GradientTape() as tape:
        tape.watch(r)
        p = tf.exp(-f(t, r))
    dp_dr = tape.gradient(p, r)
    expr = 4.0*R*(R**2-1.0)*p + D*R*dp_dr
    return tf.reduce_mean(expr**2)

# %%
# add as an objective
f.add_objective(bdry_cond)
f.add_domain(time_, 'uniform')

# %%
# learn the solution
num_samples = [10000, 10000, 10000]
f.build_db(num_samples, normalize=False)
f.solve(epochs = 1000, num_batches=10, initial_rate = 0.001)
f.save_weights()
# Out:
# Chunk #0 of domain #0 has been written.
# Chunk #0 of domain #1 has been written.
# Chunk #0 of domain #2 has been written.
# epoch = 1, batch = 1, losses = [1478142.8, 602.8684, 606593.06]
# epoch = 1, batch = 2, losses = [1526550.0, 623.8152, 588840.2]
# epoch = 1, batch = 3, losses = [1383164.8, 594.8866, 539942.2]
# epoch = 1, batch = 4, losses = [1389802.8, 640.36127, 505370.1]
# epoch = 1, batch = 5, losses = [1365766.2, 642.3986, 469816.5]
# epoch = 1, batch = 6, losses = [1396820.9, 586.36304, 421390.44]
# epoch = 1, batch = 7, losses = [1205004.8, 582.84357, 372552.5]
# epoch = 1, batch = 8, losses = [1213646.1, 565.4154, 330294.22]
# epoch = 1, batch = 9, losses = [1136117.2, 549.1562, 288919.9]
# epoch = 1, batch = 10, losses = [1043392.1, 517.79535, 262910.12]
# epoch = 2, batch = 1, losses = [1020032.0, 527.8578, 209622.4]
# epoch = 2, batch = 2, losses = [1004994.6, 541.3329, 190112.3]
# epoch = 2, batch = 3, losses = [874533.4, 510.58386, 148586.83]
# epoch = 2, batch = 4, losses = [834130.2, 546.197, 126251.31]
# epoch = 2, batch = 5, losses = [775052.6, 544.07166, 108877.89]
# epoch = 2, batch = 6, losses = [756225.2, 490.8166, 85270.39]
# epoch = 2, batch = 7, losses = [599593.56, 483.50574, 65203.77]
# epoch = 2, batch = 8, losses = [560195.8, 465.7661, 53511.71]
# epoch = 2, batch = 9, losses = [478978.25, 447.66876, 42355.836]
# epoch = 2, batch = 10, losses = [412049.72, 418.57318, 37878.535]
# epoch = 3, batch = 1, losses = [354659.53, 424.17743, 26442.615]
# epoch = 3, batch = 2, losses = [300257.16, 431.85876, 23108.213]
# epoch = 3, batch = 3, losses = [226875.23, 403.4053, 16534.424]
# epoch = 3, batch = 4, losses = [180827.84, 430.25174, 13506.724]
# epoch = 3, batch = 5, losses = [139091.3, 426.6895, 11702.258]
# epoch = 3, batch = 6, losses = [117450.34, 381.32358, 8476.911]
# epoch = 3, batch = 7, losses = [68504.15, 373.5354, 5861.3926]
# epoch = 3, batch = 8, losses = [53492.387, 358.97015, 4842.341]
# epoch = 3, batch = 9, losses = [43464.95, 343.3954, 3728.4595]
# epoch = 3, batch = 10, losses = [41360.707, 320.8902, 3568.304]
# epoch = 4, batch = 1, losses = [44749.367, 326.42798, 2422.8325]
# epoch = 4, batch = 2, losses = [56657.465, 333.76193, 2102.2944]
# epoch = 4, batch = 3, losses = [65182.746, 313.76706, 1515.732]
# epoch = 4, batch = 4, losses = [74943.27, 339.81522, 1277.2953]
# epoch = 4, batch = 5, losses = [73590.195, 342.88068, 1192.0548]
# epoch = 4, batch = 6, losses = [73382.62, 311.88367, 893.78577]
# epoch = 4, batch = 7, losses = [69114.945, 312.48883, 652.5049]
# epoch = 4, batch = 8, losses = [61753.45, 308.182, 610.9263]
# epoch = 4, batch = 9, losses = [50529.465, 302.51398, 535.55084]
# epoch = 4, batch = 10, losses = [35688.797, 290.41895, 595.0943]
# epoch = 5, batch = 1, losses = [28765.154, 303.45514, 474.91006]
# epoch = 5, batch = 2, losses = [21538.89, 318.01917, 484.184]
# epoch = 5, batch = 3, losses = [14667.9, 305.546, 415.8963]
# epoch = 5, batch = 4, losses = [11677.742, 337.29337, 412.8635]
# epoch = 5, batch = 5, losses = [9295.938, 345.498, 439.38007]
# epoch = 5, batch = 6, losses = [10763.179, 317.65262, 389.36612]
# epoch = 5, batch = 7, losses = [11827.577, 320.6416, 337.1367]
# epoch = 5, batch = 8, losses = [14126.452, 317.45532, 344.15332]
# epoch = 5, batch = 9, losses = [16872.816, 311.8642, 330.07556]
# epoch = 5, batch = 10, losses = [16825.568, 298.8846, 372.82657]
# epoch = 6, batch = 1, losses = [19392.207, 311.26312, 317.30386]
# epoch = 6, batch = 2, losses = [20123.365, 324.79007, 332.64682]
# epoch = 6, batch = 3, losses = [18790.703, 310.18896, 293.1269]
# epoch = 6, batch = 4, losses = [18998.08, 340.26456, 291.4644]
# epoch = 6, batch = 5, losses = [17178.887, 346.22302, 305.2635]
# epoch = 6, batch = 6, losses = [15745.069, 316.04352, 270.66193]
# epoch = 6, batch = 7, losses = [12756.248, 316.9137, 232.95737]
# epoch = 6, batch = 8, losses = [11259.309, 311.869, 232.96976]
# epoch = 6, batch = 9, losses = [10158.351, 304.62338, 219.63162]
# epoch = 6, batch = 10, losses = [8654.177, 290.53796, 245.05478]
# epoch = 7, batch = 1, losses = [8682.818, 301.4349, 206.3359]
# epoch = 7, batch = 2, losses = [7825.846, 313.5693, 214.5212]
# epoch = 7, batch = 3, losses = [7688.724, 298.7688, 188.23672]
# epoch = 7, batch = 4, losses = [8420.474, 327.55884, 187.64992]
# epoch = 7, batch = 5, losses = [8145.241, 333.3952, 199.27072]
# epoch = 7, batch = 6, losses = [8683.785, 304.46512, 177.35683]
# epoch = 7, batch = 7, losses = [9498.15, 305.83984, 153.40393]
# epoch = 7, batch = 8, losses = [9168.201, 301.83966, 157.288]
# epoch = 7, batch = 9, losses = [9088.028, 295.64743, 151.59662]
# epoch = 7, batch = 10, losses = [8757.194, 282.9903, 174.77411]
# epoch = 8, batch = 1, losses = [8668.041, 294.88376, 150.97743]
# epoch = 8, batch = 2, losses = [7629.965, 308.10315, 160.87422]
# epoch = 8, batch = 3, losses = [6993.658, 294.6436, 145.3829]
# epoch = 8, batch = 4, losses = [6933.493, 324.607, 148.84853]
# epoch = 8, batch = 5, losses = [6401.448, 331.7781, 161.74333]
# epoch = 8, batch = 6, losses = [6571.929, 303.69873, 147.69336]
# epoch = 8, batch = 7, losses = [6408.319, 305.8742, 131.22678]
# epoch = 8, batch = 8, losses = [6655.2344, 302.5645, 136.77728]
# epoch = 8, batch = 9, losses = [6726.803, 296.63138, 133.94395]
# epoch = 8, batch = 10, losses = [6358.59, 284.12134, 154.59901]
# epoch = 9, batch = 1, losses = [6878.81, 296.21024, 135.24602]
# epoch = 9, batch = 2, losses = [6463.0977, 309.51297, 144.35066]
# epoch = 9, batch = 3, losses = [6076.2427, 295.71844, 131.14168]
# epoch = 9, batch = 4, losses = [6277.169, 325.5878, 134.01956]
# epoch = 9, batch = 5, losses = [6188.482, 332.41962, 144.64809]
# epoch = 9, batch = 6, losses = [6261.6865, 303.75476, 131.90512]
# epoch = 9, batch = 7, losses = [5783.881, 305.49026, 116.92505]
# epoch = 9, batch = 8, losses = [5946.897, 301.7789, 120.95923]
# epoch = 9, batch = 9, losses = [5798.371, 295.46, 117.71628]
# epoch = 9, batch = 10, losses = [5577.914, 282.6942, 134.8245]
# epoch = 10, batch = 1, losses = [5901.409, 294.48868, 117.41325]
# epoch = 10, batch = 2, losses = [5362.649, 307.55414, 124.76323]
# epoch = 10, batch = 3, losses = [5226.599, 293.75934, 113.041794]
# epoch = 10, batch = 4, losses = [5463.824, 323.4482, 115.33839]
# epoch = 10, batch = 5, losses = [5191.9233, 330.34045, 124.41985]
# epoch = 10, batch = 6, losses = [5371.623, 301.9995, 113.46595]
# epoch = 10, batch = 7, losses = [5376.195, 303.94614, 100.72312]
# epoch = 10, batch = 8, losses = [5461.164, 300.51862, 104.464516]
# epoch = 10, batch = 9, losses = [5386.8926, 294.48837, 101.966515]
# epoch = 10, batch = 10, losses = [5225.897, 282.02942, 116.83535]
# epoch = 11, batch = 1, losses = [5445.6973, 294.0855, 102.21856]
# epoch = 11, batch = 2, losses = [4903.689, 307.44403, 108.62207]
# epoch = 11, batch = 3, losses = [4722.5264, 293.8628, 98.8877]
# epoch = 11, batch = 4, losses = [4899.6514, 323.82535, 101.0173]
# epoch = 11, batch = 5, losses = [4778.375, 330.9317, 108.78618]
# epoch = 11, batch = 6, losses = [4952.275, 302.56992, 99.43723]
# epoch = 11, batch = 7, losses = [4747.187, 304.56256, 88.52438]
# epoch = 11, batch = 8, losses = [5049.4355, 301.13, 91.65003]
# epoch = 11, batch = 9, losses = [4906.244, 294.9914, 89.35896]
# epoch = 11, batch = 10, losses = [4744.0596, 282.40765, 101.66215]
# epoch = 12, batch = 1, losses = [4956.3213, 294.38156, 89.06989]
# epoch = 12, batch = 2, losses = [4543.185, 307.6616, 94.044235]
# epoch = 12, batch = 3, losses = [4347.099, 293.9086, 85.69755]
# epoch = 12, batch = 4, losses = [4507.542, 323.77246, 87.3032]
# epoch = 12, batch = 5, losses = [4440.145, 330.76816, 93.6795]
# epoch = 12, batch = 6, losses = [4560.3735, 302.2659, 85.60385]
# epoch = 12, batch = 7, losses = [4352.716, 304.17535, 76.25328]
# epoch = 12, batch = 8, losses = [4658.042, 300.6972, 78.9522]
# epoch = 12, batch = 9, losses = [4544.8335, 294.52374, 77.04853]
# epoch = 12, batch = 10, losses = [4424.534, 281.95682, 87.53208]
# epoch = 13, batch = 1, losses = [4592.284, 293.9483, 77.035675]
# epoch = 13, batch = 2, losses = [4190.3726, 307.2942, 81.24296]
# epoch = 13, batch = 3, losses = [4037.144, 293.62686, 74.4486]
# epoch = 13, batch = 4, losses = [4195.657, 323.5777, 76.052155]
# epoch = 13, batch = 5, losses = [4119.2856, 330.69513, 81.7304]
# epoch = 13, batch = 6, losses = [4208.959, 302.28082, 75.004005]
# epoch = 13, batch = 7, losses = [4018.6516, 304.29236, 67.15181]
# epoch = 13, batch = 8, losses = [4343.006, 300.89713, 69.73545]
# epoch = 13, batch = 9, losses = [4224.8066, 294.77686, 68.271866]
# epoch = 13, batch = 10, losses = [4109.831, 282.23853, 77.40867]
# epoch = 14, batch = 1, losses = [4241.2915, 294.27267, 68.48299]
# epoch = 14, batch = 2, losses = [3917.6655, 307.67612, 72.024376]
# epoch = 14, batch = 3, losses = [3741.7861, 293.9787, 66.28808]
# epoch = 14, batch = 4, losses = [3908.9316, 323.9508, 67.715546]
# epoch = 14, batch = 5, losses = [3870.0022, 331.04675, 72.619545]
# epoch = 14, batch = 6, losses = [3919.777, 302.52567, 66.72369]
# epoch = 14, batch = 7, losses = [3722.302, 304.4791, 59.834103]
# epoch = 14, batch = 8, losses = [4070.2952, 301.01456, 62.1047]
# epoch = 14, batch = 9, losses = [3954.2034, 294.81192, 60.798992]
# epoch = 14, batch = 10, losses = [3854.0203, 282.20316, 68.66106]
# epoch = 15, batch = 1, losses = [3953.3948, 294.1822, 60.920593]
# epoch = 15, batch = 2, losses = [3663.808, 307.56073, 63.80799]
# epoch = 15, batch = 3, losses = [3498.9575, 293.82272, 58.922054]
# epoch = 15, batch = 4, losses = [3662.5793, 323.7717, 60.19405]
# epoch = 15, batch = 5, losses = [3618.0493, 330.86765, 64.48872]
# epoch = 15, batch = 6, losses = [3650.7744, 302.32785, 59.351936]
# epoch = 15, batch = 7, losses = [3469.7444, 304.28378, 53.350563]
# epoch = 15, batch = 8, losses = [3822.5896, 300.83093, 55.45727]
# epoch = 15, batch = 9, losses = [3716.9058, 294.62204, 54.38765]
# epoch = 15, batch = 10, losses = [3624.607, 282.02023, 61.29633]
# epoch = 16, batch = 1, losses = [3692.1335, 294.00467, 54.629524]
# epoch = 16, batch = 2, losses = [3447.7776, 307.40958, 57.048306]
# epoch = 16, batch = 3, losses = [3280.119, 293.6648, 52.917736]
# epoch = 16, batch = 4, losses = [3440.2812, 323.61996, 54.09744]
# epoch = 16, batch = 5, losses = [3413.699, 330.72375, 57.90414]
# epoch = 16, batch = 6, losses = [3425.782, 302.1423, 53.383]
# epoch = 16, batch = 7, losses = [3240.7466, 304.072, 48.08605]
# epoch = 16, batch = 8, losses = [3607.429, 300.59424, 50.018696]
# epoch = 16, batch = 9, losses = [3498.9492, 294.33176, 49.09397]
# epoch = 16, batch = 10, losses = [3416.7915, 281.69424, 55.16096]
# epoch = 17, batch = 1, losses = [3461.0884, 293.63165, 49.321312]
# epoch = 17, batch = 2, losses = [3255.8965, 307.00516, 51.30526]
# epoch = 17, batch = 3, losses = [3089.8135, 293.22272, 47.747116]
# epoch = 17, batch = 4, losses = [3246.7654, 323.12454, 48.806313]
# epoch = 17, batch = 5, losses = [3217.5972, 330.2057, 52.171]
# epoch = 17, batch = 6, losses = [3212.75, 301.59967, 48.14507]
# epoch = 17, batch = 7, losses = [3045.7153, 303.49756, 43.430977]
# epoch = 17, batch = 8, losses = [3407.513, 300.0086, 45.206753]
# epoch = 17, batch = 9, losses = [3306.1292, 293.7105, 44.408554]
# epoch = 17, batch = 10, losses = [3235.3079, 281.0693, 49.77339]
# epoch = 18, batch = 1, losses = [3257.5427, 292.97208, 44.648804]
# epoch = 18, batch = 2, losses = [3083.162, 306.32443, 46.28585]
# epoch = 18, batch = 3, losses = [2919.8152, 292.53412, 43.223785]
# epoch = 18, batch = 4, losses = [3071.8054, 322.3871, 44.191036]
# epoch = 18, batch = 5, losses = [3046.7593, 329.46234, 47.186462]
# epoch = 18, batch = 6, losses = [3027.9634, 300.8533, 43.590557]
# epoch = 18, batch = 7, losses = [2868.0696, 302.72116, 39.377792]
# epoch = 18, batch = 8, losses = [3230.0745, 299.22562, 41.01187]
# epoch = 18, batch = 9, losses = [3127.5369, 292.88416, 40.314156]
# epoch = 18, batch = 10, losses = [3067.3345, 280.23737, 45.067223]
# epoch = 19, batch = 1, losses = [3072.117, 292.08813, 40.54282]
# epoch = 19, batch = 2, losses = [2927.922, 305.3947, 41.87746]
# epoch = 19, batch = 3, losses = [2766.7058, 291.58786, 39.223488]
# epoch = 19, batch = 4, losses = [2912.904, 321.3601, 40.098618]
# epoch = 19, batch = 5, losses = [2890.7163, 328.41495, 42.767082]
# epoch = 19, batch = 6, losses = [2860.491, 299.81296, 39.5374]
# epoch = 19, batch = 7, losses = [2709.845, 301.64252, 35.755665]
# epoch = 19, batch = 8, losses = [3066.39, 298.14587, 37.26153]
# epoch = 19, batch = 9, losses = [2965.3042, 291.76468, 36.652046]
# epoch = 19, batch = 10, losses = [2916.6904, 279.12924, 40.886616]
# epoch = 20, batch = 1, losses = [2906.385, 290.9277, 36.88261]
# epoch = 20, batch = 2, losses = [2785.0745, 304.18524, 37.977806]
# epoch = 20, batch = 3, losses = [2628.8364, 290.38055, 35.67499]
# epoch = 20, batch = 4, losses = [2767.8994, 320.06497, 36.4773]
# epoch = 20, batch = 5, losses = [2748.034, 327.10922, 38.87217]
# epoch = 20, batch = 6, losses = [2708.3298, 298.53888, 35.96512]
# epoch = 20, batch = 7, losses = [2566.379, 300.33466, 32.559864]
# epoch = 20, batch = 8, losses = [2916.7542, 296.84772, 33.952362]
# epoch = 20, batch = 9, losses = [2813.968, 290.4296, 33.417694]
# epoch = 20, batch = 10, losses = [2776.944, 277.8148, 37.20604]
# epoch = 21, batch = 1, losses = [2754.4915, 289.55478, 33.6433]
# epoch = 21, batch = 2, losses = [2654.2258, 302.7515, 34.539062]
# epoch = 21, batch = 3, losses = [2503.0784, 288.95148, 32.526634]
# epoch = 21, batch = 4, losses = [2633.9868, 318.5297, 33.259148]
# epoch = 21, batch = 5, losses = [2616.4214, 325.55875, 35.41211]
# epoch = 21, batch = 6, losses = [2569.24, 297.0319, 32.781673]
# epoch = 21, batch = 7, losses = [2435.676, 298.7897, 29.701214]
# epoch = 21, batch = 8, losses = [2778.0237, 295.31787, 30.987385]
# epoch = 21, batch = 9, losses = [2673.5906, 288.86407, 30.515024]
# epoch = 21, batch = 10, losses = [2648.1545, 276.28128, 33.917637]
# epoch = 22, batch = 1, losses = [2615.5728, 287.96014, 30.735481]
# epoch = 22, batch = 2, losses = [2531.766, 301.09027, 31.470304]
# epoch = 22, batch = 3, losses = [2387.6675, 287.3062, 29.705]
# epoch = 22, batch = 4, losses = [2509.3672, 316.76947, 30.377426]
# epoch = 22, batch = 5, losses = [2494.2625, 323.78845, 32.322483]
# epoch = 22, batch = 6, losses = [2441.6326, 295.32352, 29.936968]
# epoch = 22, batch = 7, losses = [2315.1611, 297.04596, 27.143]
# epoch = 22, batch = 8, losses = [2649.1375, 293.5985, 28.333466]
# epoch = 22, batch = 9, losses = [2541.663, 287.11243, 27.915218]
# epoch = 22, batch = 10, losses = [2527.404, 274.5714, 30.983932]
# epoch = 23, batch = 1, losses = [2486.7078, 286.18646, 28.129995]
# epoch = 23, batch = 2, losses = [2417.2905, 299.24292, 28.734]
# epoch = 23, batch = 3, losses = [2280.7478, 285.4804, 27.176609]
# epoch = 23, batch = 4, losses = [2392.7305, 314.81708, 27.793974]
# epoch = 23, batch = 5, losses = [2380.0144, 321.8255, 29.556385]
# epoch = 23, batch = 6, losses = [2323.0864, 293.43442, 27.38521]
# epoch = 23, batch = 7, losses = [2203.612, 295.1203, 24.84238]
# epoch = 23, batch = 8, losses = [2528.177, 291.70294, 25.94393]
# epoch = 23, batch = 9, losses = [2417.6125, 285.18655, 25.57144]
# epoch = 23, batch = 10, losses = [2414.2349, 272.69647, 28.349173]
# epoch = 24, batch = 1, losses = [2366.9985, 284.2457, 25.779755]
# epoch = 24, batch = 2, losses = [2309.0964, 297.2237, 26.278664]
# epoch = 24, batch = 3, losses = [2181.0645, 283.49088, 24.89798]
# epoch = 24, batch = 4, losses = [2282.983, 312.69308, 25.466154]
# epoch = 24, batch = 5, losses = [2272.5833, 319.6937, 27.068684]
# epoch = 24, batch = 6, losses = [2212.5623, 291.39044, 25.087986]
# epoch = 24, batch = 7, losses = [2099.4172, 293.0412, 22.767889]
# epoch = 24, batch = 8, losses = [2414.303, 289.66068, 23.787968]
# epoch = 24, batch = 9, losses = [2300.226, 283.1168, 23.454899]
# epoch = 24, batch = 10, losses = [2307.097, 270.68555, 25.97798]
# epoch = 25, batch = 1, losses = [2254.7302, 282.16724, 23.656258]
# epoch = 25, batch = 2, losses = [2206.6208, 295.06198, 24.070482]
# epoch = 25, batch = 3, losses = [2087.391, 281.36414, 22.840036]
# epoch = 25, batch = 4, losses = [2179.1768, 310.424, 23.36337]
# epoch = 25, batch = 5, losses = [2171.145, 317.41757, 24.824839]
# epoch = 25, batch = 6, losses = [2108.9265, 289.21237, 23.01326]
# epoch = 25, batch = 7, losses = [2001.6371, 290.828, 20.891075]
# epoch = 25, batch = 8, losses = [2306.508, 287.48938, 21.83587]
# epoch = 25, batch = 9, losses = [2189.0078, 280.92014, 21.536777]
# epoch = 25, batch = 10, losses = [2205.4805, 268.55484, 23.836342]
# epoch = 26, batch = 1, losses = [2149.1387, 279.96783, 21.731468]
# epoch = 26, batch = 2, losses = [2109.069, 292.77585, 22.078203]
# epoch = 26, batch = 3, losses = [1998.9325, 279.119, 20.976456]
# epoch = 26, batch = 4, losses = [2080.6772, 308.03058, 21.459438]
# epoch = 26, batch = 5, losses = [2074.939, 315.0188, 22.796314]
# epoch = 26, batch = 6, losses = [2011.2473, 286.92172, 21.136066]
# epoch = 26, batch = 7, losses = [1909.439, 288.50323, 19.190674]
# epoch = 26, batch = 8, losses = [2204.166, 285.2112, 20.06607]
# epoch = 26, batch = 9, losses = [2083.2917, 278.61887, 19.796555]
# epoch = 26, batch = 10, losses = [2108.612, 266.32547, 21.898813]
# epoch = 27, batch = 1, losses = [2049.2856, 277.66867, 19.984303]
# epoch = 27, batch = 2, losses = [2016.038, 290.38654, 20.277145]
# epoch = 27, batch = 3, losses = [1914.9768, 276.77518, 19.285645]
# epoch = 27, batch = 4, losses = [1986.9231, 305.53278, 19.73177]
# epoch = 27, batch = 5, losses = [1983.3994, 312.51645, 20.957891]
# epoch = 27, batch = 6, losses = [1918.838, 284.53577, 19.433195]
# epoch = 27, batch = 7, losses = [1822.1837, 286.08347, 17.646097]
# epoch = 27, batch = 8, losses = [2106.6936, 282.84207, 18.457436]
# epoch = 27, batch = 9, losses = [1982.7043, 276.2286, 18.213564]
# epoch = 27, batch = 10, losses = [2016.0785, 264.01242, 20.141027]
# epoch = 28, batch = 1, losses = [1954.5793, 275.28506, 18.39446]
# epoch = 28, batch = 2, losses = [1927.0997, 287.9102, 18.644535]
# epoch = 28, batch = 3, losses = [1834.967, 274.3487, 17.748222]
# epoch = 28, batch = 4, losses = [1897.473, 302.9479, 18.160833]
# epoch = 28, batch = 5, losses = [1896.108, 309.92804, 19.288227]
# epoch = 28, batch = 6, losses = [1831.159, 282.07104, 17.885546]
# epoch = 28, batch = 7, losses = [1739.3163, 283.58554, 16.240808]
# epoch = 28, batch = 8, losses = [2013.6554, 280.39807, 16.992992]
# epoch = 28, batch = 9, losses = [1886.8306, 273.7653, 16.771555]
# epoch = 28, batch = 10, losses = [1927.4432, 261.63074, 18.543446]
# epoch = 29, batch = 1, losses = [1864.4542, 272.83206, 16.945585]
# epoch = 29, batch = 2, losses = [1841.9645, 285.36203, 17.16171]
# epoch = 29, batch = 3, losses = [1758.4583, 271.854, 16.347906]
# epoch = 29, batch = 4, losses = [1811.976, 300.2908, 16.72988]
# epoch = 29, batch = 5, losses = [1812.6477, 307.2679, 17.76883]
# epoch = 29, batch = 6, losses = [1747.6906, 279.54095, 16.476265]
# epoch = 29, batch = 7, losses = [1660.4203, 281.0227, 14.959978]
# epoch = 29, batch = 8, losses = [1924.6488, 277.892, 15.657505]
# epoch = 29, batch = 9, losses = [1795.3649, 271.2416, 15.455812]
# epoch = 29, batch = 10, losses = [1842.4048, 259.19254, 17.088696]
# epoch = 30, batch = 1, losses = [1778.4788, 270.3221, 15.623176]
# epoch = 30, batch = 2, losses = [1760.3595, 282.75497, 15.812457]
# epoch = 30, batch = 3, losses = [1685.0767, 269.30365, 15.070538]
# epoch = 30, batch = 4, losses = [1730.1165, 297.5747, 15.424485]
# epoch = 30, batch = 5, losses = [1732.719, 304.54922, 16.384012]
# epoch = 30, batch = 6, losses = [1668.0564, 276.95773, 15.1911125]
# epoch = 30, batch = 7, losses = [1585.1117, 278.4072, 13.791068]
# epoch = 30, batch = 8, losses = [1839.3591, 275.33566, 14.438176]
# epoch = 30, batch = 9, losses = [1708.0043, 268.66916, 14.253879]
# epoch = 30, batch = 10, losses = [1760.676, 256.70874, 15.762069]
# epoch = 31, batch = 1, losses = [1696.27, 267.76602, 14.414706]
# epoch = 31, batch = 2, losses = [1682.045, 280.10013, 14.582836]
# epoch = 31, batch = 3, losses = [1614.5168, 266.70813, 13.903784]
# epoch = 31, batch = 4, losses = [1651.6305, 294.81055, 14.232107]
# epoch = 31, batch = 5, losses = [1656.0192, 301.78278, 15.120069]
# epoch = 31, batch = 6, losses = [1591.8975, 274.33157, 14.017663]
# epoch = 31, batch = 7, losses = [1513.0868, 275.74908, 12.723096]
# epoch = 31, batch = 8, losses = [1757.491, 272.73868, 13.32365]
# epoch = 31, batch = 9, losses = [1624.484, 266.0574, 13.154754]
# epoch = 31, batch = 10, losses = [1682.0192, 254.1884, 14.5507555]
# epoch = 32, batch = 1, losses = [1617.507, 265.17316, 13.309263]
# epoch = 32, batch = 2, losses = [1606.805, 277.40692, 13.460777]
# epoch = 32, batch = 3, losses = [1546.5198, 264.0768, 12.837069]
# epoch = 32, batch = 4, losses = [1576.2772, 292.00803, 13.141924]
# epoch = 32, batch = 5, losses = [1582.3014, 298.97812, 13.965185]
# epoch = 32, batch = 6, losses = [1518.9143, 271.67123, 12.945087]
# epoch = 32, batch = 7, losses = [1444.072, 273.05707, 11.746407]
# epoch = 32, batch = 8, losses = [1678.7925, 270.1093, 12.303979]
# epoch = 32, batch = 9, losses = [1544.5574, 263.41464, 12.148825]
# epoch = 32, batch = 10, losses = [1606.2252, 251.63922, 13.443525]
# epoch = 33, batch = 1, losses = [1541.9122, 262.55118, 12.297245]
# epoch = 33, batch = 2, losses = [1534.442, 274.68332, 12.435746]
# epoch = 33, batch = 3, losses = [1480.8628, 261.4171, 11.860934]
# epoch = 33, batch = 4, losses = [1503.8466, 289.175, 12.144227]
# epoch = 33, batch = 5, losses = [1511.338, 296.14288, 12.908859]
# epoch = 33, batch = 6, losses = [1448.8436, 268.98386, 11.9637985]
# epoch = 33, batch = 7, losses = [1377.8295, 270.3383, 10.852514]
# epoch = 33, batch = 8, losses = [1603.0382, 267.4545, 11.3703985]
# epoch = 33, batch = 9, losses = [1467.9976, 260.74753, 11.227491]
# epoch = 33, batch = 10, losses = [1533.1061, 249.06766, 12.430533]
# epoch = 34, batch = 1, losses = [1469.2478, 259.9066, 11.370111]
# epoch = 34, batch = 2, losses = [1464.7717, 271.93594, 11.498447]
# epoch = 34, batch = 3, losses = [1417.3625, 258.73547, 10.967046]
# epoch = 34, batch = 4, losses = [1434.1512, 286.31818, 11.230585]
# epoch = 34, batch = 5, losses = [1442.9368, 293.28375, 11.941947]
# epoch = 34, batch = 6, losses = [1381.4607, 266.27567, 11.065407]
# epoch = 34, batch = 7, losses = [1314.1559, 267.59882, 10.033874]
# epoch = 34, batch = 8, losses = [1530.0262, 264.78, 10.515129]
# epoch = 34, batch = 9, losses = [1394.5986, 258.06186, 10.383256]
# epoch = 34, batch = 10, losses = [1462.5033, 246.47919, 11.503098]
# epoch = 35, batch = 1, losses = [1399.3127, 257.2448, 10.520245]
# epoch = 35, batch = 2, losses = [1397.6272, 269.1703, 10.640728]
# epoch = 35, batch = 3, losses = [1355.858, 256.03705, 10.147971]
# epoch = 35, batch = 4, losses = [1367.019, 283.44293, 10.393363]
# epoch = 35, batch = 5, losses = [1376.9203, 290.40588, 11.056227]
# epoch = 35, batch = 6, losses = [1316.5653, 263.55154, 10.242344]
# epoch = 35, batch = 7, losses = [1252.8682, 264.84363, 9.283747]
# epoch = 35, batch = 8, losses = [1459.578, 262.0907, 9.731218]
# epoch = 35, batch = 9, losses = [1324.1677, 255.36237, 9.609226]
# epoch = 35, batch = 10, losses = [1394.2656, 243.87814, 10.653418]
# epoch = 36, batch = 1, losses = [1331.9232, 254.57043, 9.740885]
# epoch = 36, batch = 2, losses = [1332.858, 266.39102, 9.855264]
# epoch = 36, batch = 3, losses = [1296.2185, 253.32649, 9.397099]
# epoch = 36, batch = 4, losses = [1302.3016, 280.554, 9.625788]
# epoch = 36, batch = 5, losses = [1313.1412, 287.51395, 10.24442]
# epoch = 36, batch = 6, losses = [1253.9847, 260.81567, 9.487879]
# epoch = 36, batch = 7, losses = [1193.8083, 262.07678, 8.59603]
# epoch = 36, batch = 8, losses = [1391.5344, 259.3904, 9.012345]
# epoch = 36, batch = 9, losses = [1256.5331, 252.65282, 8.899255]
# epoch = 36, batch = 10, losses = [1328.2725, 241.26828, 9.874531]
# epoch = 37, batch = 1, losses = [1266.9294, 251.88719, 9.025869]
# epoch = 37, batch = 2, losses = [1270.3292, 263.60187, 9.135561]
# epoch = 37, batch = 3, losses = [1238.3314, 250.60732, 8.708438]
# epoch = 37, batch = 4, losses = [1239.8643, 277.65512, 8.921782]
# epoch = 37, batch = 5, losses = [1251.4725, 284.61188, 9.500047]
# epoch = 37, batch = 6, losses = [1193.58, 258.07184, 8.7960615]
# epoch = 37, batch = 7, losses = [1136.8394, 259.3021, 7.9653945]
# epoch = 37, batch = 8, losses = [1325.7622, 256.68274, 8.352947]
# epoch = 37, batch = 9, losses = [1191.5393, 249.93681, 8.247921]
# epoch = 37, batch = 10, losses = [1264.4178, 238.65294, 9.160287]
# epoch = 38, batch = 1, losses = [1204.2043, 249.19829, 8.369703]
# epoch = 38, batch = 2, losses = [1209.9209, 260.80637, 8.475854]
# epoch = 38, batch = 3, losses = [1182.1096, 247.88287, 8.076679]
# epoch = 38, batch = 4, losses = [1179.5947, 274.7499, 8.275905]
# epoch = 38, batch = 5, losses = [1191.8008, 281.70285, 8.817214]
# epoch = 38, batch = 6, losses = [1135.224, 255.32301, 8.161441]
# epoch = 38, batch = 7, losses = [1081.8431, 256.5225, 7.3868914]
# epoch = 38, batch = 8, losses = [1262.1444, 253.97064, 7.7479362]
# epoch = 38, batch = 9, losses = [1129.0491, 247.21727, 7.650222]
# epoch = 38, batch = 10, losses = [1202.6115, 236.03485, 8.505055]
# epoch = 39, batch = 1, losses = [1143.6321, 246.50671, 7.767416]
# epoch = 39, batch = 2, losses = [1151.5337, 258.00732, 7.8708935]
# epoch = 39, batch = 3, losses = [1127.4846, 245.15594, 7.4969387]
# epoch = 39, batch = 4, losses = [1121.395, 271.84113, 7.683169]
# epoch = 39, batch = 5, losses = [1134.0432, 278.78986, 8.190661]
# epoch = 39, batch = 6, losses = [1078.823, 252.57196, 7.57915]
# epoch = 39, batch = 7, losses = [1028.7217, 253.74077, 6.856133]
# epoch = 39, batch = 8, losses = [1200.586, 251.25674, 7.1927266]
# epoch = 39, batch = 9, losses = [1068.9467, 244.4968, 7.101635]
# epoch = 39, batch = 10, losses = [1142.7852, 233.41656, 7.9038196]
# epoch = 40, batch = 1, losses = [1085.128, 243.81493, 7.21449]
# epoch = 40, batch = 2, losses = [1095.0842, 255.20738, 7.3159795]
# epoch = 40, batch = 3, losses = [1074.4082, 242.42906, 6.9648757]
# epoch = 40, batch = 4, losses = [1065.1897, 268.93152, 7.1391377]
# epoch = 40, batch = 5, losses = [1078.1277, 275.8755, 7.6156044]
# epoch = 40, batch = 6, losses = [1024.2964, 249.82117, 7.044759]
# epoch = 40, batch = 7, losses = [977.3975, 250.9593, 6.3690734]
# epoch = 40, batch = 8, losses = [1141.0103, 248.54327, 6.6831055]
# epoch = 40, batch = 9, losses = [1011.1363, 241.77762, 6.5980554]
# epoch = 40, batch = 10, losses = [1084.888, 230.80025, 7.3519883]
# epoch = 41, batch = 1, losses = [1028.619, 241.12517, 6.706802]
# epoch = 41, batch = 2, losses = [1040.5057, 252.40868, 6.8068094]
# epoch = 41, batch = 3, losses = [1022.8511, 239.70432, 6.4764366]
# epoch = 41, batch = 4, losses = [1010.91656, 266.02322, 6.6396766]
# epoch = 41, batch = 5, losses = [1024.0061, 272.96185, 7.0876822]
# epoch = 41, batch = 6, losses = [971.59375, 247.0727, 6.5542336]
# epoch = 41, batch = 7, losses = [927.81573, 248.18016, 5.9220505]
# epoch = 41, batch = 8, losses = [1083.3689, 245.83238, 6.2152934]
# epoch = 41, batch = 9, losses = [955.54736, 239.0618, 6.1357393]
# epoch = 41, batch = 10, losses = [1028.894, 228.18777, 6.845394]
# epoch = 42, batch = 1, losses = [974.06165, 238.43939, 6.2406116]
# epoch = 42, batch = 2, losses = [987.75635, 249.61333, 6.339549]
# epoch = 42, batch = 3, losses = [972.8063, 236.98372, 6.0280266]
# epoch = 42, batch = 4, losses = [958.54333, 263.11832, 6.1810937]
# epoch = 42, batch = 5, losses = [971.65125, 270.05103, 6.602938]
# epoch = 42, batch = 6, losses = [920.6829, 244.32823, 6.1038594]
# epoch = 42, batch = 7, losses = [879.9435, 245.4051, 5.5116887]
# epoch = 42, batch = 8, losses = [1027.6321, 243.12563, 5.785746]
# epoch = 42, batch = 9, losses = [902.13477, 236.35092, 5.7112036]
# epoch = 42, batch = 10, losses = [974.796, 225.58067, 6.3801737]
# epoch = 43, batch = 1, losses = [921.4295, 235.75903, 5.812394]
# epoch = 43, batch = 2, losses = [936.8127, 246.8227, 5.9105434]
# epoch = 43, batch = 3, losses = [924.2897, 234.26848, 5.6161866]
# epoch = 43, batch = 4, losses = [908.05225, 260.21808, 5.7598715]
# epoch = 43, batch = 5, losses = [921.06165, 267.1442, 6.1576624]
# epoch = 43, batch = 6, losses = [871.5645, 241.58905, 5.6901894]
# epoch = 43, batch = 7, losses = [833.77515, 242.63522, 5.134831]
# epoch = 43, batch = 8, losses = [973.7987, 240.42406, 5.3911915]
# epoch = 43, batch = 9, losses = [850.88293, 233.64601, 5.3212132]
# epoch = 43, batch = 10, losses = [922.613, 222.97981, 5.95274]
# epoch = 44, batch = 1, losses = [870.7247, 233.085, 5.418883]
# epoch = 44, batch = 2, losses = [887.67114, 244.03764, 5.5164394]
# epoch = 44, batch = 3, losses = [877.3327, 231.55957, 5.2377634]
# epoch = 44, batch = 4, losses = [859.45056, 257.32336, 5.3727674]
# epoch = 44, batch = 5, losses = [872.2488, 264.24216, 5.748389]
# epoch = 44, batch = 6, losses = [824.2588, 238.85582, 5.310011]
# epoch = 44, batch = 7, losses = [789.3245, 239.87125, 4.788536]
# epoch = 44, batch = 8, losses = [921.8875, 237.72829, 5.028547]
# epoch = 44, batch = 9, losses = [801.80286, 230.94751, 4.96271]
# epoch = 44, batch = 10, losses = [872.38, 220.38576, 5.559735]
# epoch = 45, batch = 1, losses = [821.9715, 230.41776, 5.0570064]
# epoch = 45, batch = 2, losses = [840.3493, 241.25851, 5.154087]
# epoch = 45, batch = 3, losses = [831.9846, 228.85704, 4.88971]
# epoch = 45, batch = 4, losses = [812.75714, 254.43427, 5.0166707]
# epoch = 45, batch = 5, losses = [825.24554, 261.34485, 5.371807]
# epoch = 45, batch = 6, losses = [778.8071, 236.12845, 4.960217]
# epoch = 45, batch = 7, losses = [746.62427, 237.11287, 4.469951]
# epoch = 45, batch = 8, losses = [871.9338, 235.03798, 4.6948166]
# epoch = 45, batch = 9, losses = [754.9194, 228.25528, 4.632761]
# epoch = 45, batch = 10, losses = [824.143, 217.79807, 5.1978908]
# epoch = 46, batch = 1, losses = [775.20416, 227.75679, 4.7237597]
# epoch = 46, batch = 2, losses = [794.86786, 238.48477, 4.820427]
# epoch = 46, batch = 3, losses = [788.2935, 226.16045, 4.569159]
# epoch = 46, batch = 4, losses = [767.99677, 251.55008, 4.688621]
# epoch = 46, batch = 5, losses = [780.088, 258.45148, 5.0247717]
# epoch = 46, batch = 6, losses = [735.2594, 233.40613, 4.63785]
# epoch = 46, batch = 7, losses = [705.7105, 234.35938, 4.176377]
# epoch = 46, batch = 8, losses = [823.9781, 232.35228, 4.3871865]
# epoch = 46, batch = 9, losses = [710.267, 225.56824, 4.32855]
# epoch = 46, batch = 10, losses = [777.94916, 215.21593, 4.864115]
# epoch = 47, batch = 1, losses = [730.4631, 225.10114, 4.416326]
# epoch = 47, batch = 2, losses = [751.252, 235.71524, 4.512536]
# epoch = 47, batch = 3, losses = [746.3031, 223.46866, 4.2733097]
# epoch = 47, batch = 4, losses = [725.1865, 248.66965, 4.3857784]
# epoch = 47, batch = 5, losses = [736.81036, 255.5609, 4.7042427]
# epoch = 47, batch = 6, losses = [693.66547, 230.6878, 4.3401055]
# epoch = 47, batch = 7, losses = [666.6132, 231.60959, 3.9052446]
# epoch = 47, batch = 8, losses = [778.05365, 229.67017, 4.1029716]
# epoch = 47, batch = 9, losses = [667.8669, 222.8854, 4.047429]
# epoch = 47, batch = 10, losses = [733.8266, 212.63824, 4.555461]
# epoch = 48, batch = 1, losses = [687.78015, 222.44986, 4.132024]
# epoch = 48, batch = 2, losses = [709.5167, 232.94894, 4.2276964]
# epoch = 48, batch = 3, losses = [706.0354, 220.78073, 3.9995713]
# epoch = 48, batch = 4, losses = [684.325, 245.79192, 4.1054773]
# epoch = 48, batch = 5, losses = [695.428, 252.67203, 4.407423]
# epoch = 48, batch = 6, losses = [654.053, 227.97266, 4.064358]
# epoch = 48, batch = 7, losses = [629.3405, 228.86267, 3.654157]
# epoch = 48, batch = 8, losses = [734.17236, 226.99084, 3.839683]
# epoch = 48, batch = 9, losses = [627.7104, 220.2062, 3.7869675]
# epoch = 48, batch = 10, losses = [691.7763, 210.06462, 4.2692375]
# epoch = 49, batch = 1, losses = [647.1634, 219.80261, 3.8684056]
# epoch = 49, batch = 2, losses = [669.66235, 230.18556, 3.9633906]
# epoch = 49, batch = 3, losses = [667.48865, 218.09648, 3.7455883]
# epoch = 49, batch = 4, losses = [645.39014, 242.91685, 3.8453264]
# epoch = 49, batch = 5, losses = [655.93463, 249.78493, 4.1317606]
# epoch = 49, batch = 6, losses = [616.4219, 225.26086, 3.8082688]
# epoch = 49, batch = 7, losses = [593.8768, 226.11916, 3.4210176]
# epoch = 49, batch = 8, losses = [692.3237, 224.315, 3.5951405]
# epoch = 49, batch = 9, losses = [589.758, 217.53145, 3.5450215]
# epoch = 49, batch = 10, losses = [651.77295, 207.49602, 4.003105]
# epoch = 50, batch = 1, losses = [608.601, 217.16042, 3.6233535]
# epoch = 50, batch = 2, losses = [631.673, 227.42657, 3.7174962]
# epoch = 50, batch = 3, losses = [630.6424, 215.41748, 3.5093608]
# epoch = 50, batch = 4, losses = [608.34265, 240.0463, 3.6032956]
# epoch = 50, batch = 5, losses = [618.3105, 246.90186, 3.8751304]
# epoch = 50, batch = 6, losses = [580.74524, 222.5548, 3.5698876]
# epoch = 50, batch = 7, losses = [560.1872, 223.38152, 3.204061]
# epoch = 50, batch = 8, losses = [652.47766, 221.64536, 3.367536]
# epoch = 50, batch = 9, losses = [553.9456, 214.86407, 3.3198342]
# epoch = 50, batch = 10, losses = [613.77264, 204.93547, 3.7551196]
# epoch = 51, batch = 1, losses = [572.061, 214.52684, 3.3951457]
# epoch = 51, batch = 2, losses = [595.5257, 224.6756, 3.488249]
# epoch = 51, batch = 3, losses = [595.4694, 212.74779, 3.2892704]
# epoch = 51, batch = 4, losses = [573.1388, 237.18494, 3.3777716]
# epoch = 51, batch = 5, losses = [582.52246, 244.02754, 3.635833]
# epoch = 51, batch = 6, losses = [546.9702, 219.85925, 3.3476665]
# epoch = 51, batch = 7, losses = [528.22546, 220.65497, 3.0019238]
# epoch = 51, batch = 8, losses = [614.59174, 218.98703, 3.15546]
# epoch = 51, batch = 9, losses = [520.1931, 212.20949, 3.11004]
# epoch = 51, batch = 10, losses = [577.721, 202.38847, 3.523811]
# epoch = 52, batch = 1, losses = [537.5003, 211.90753, 3.18245]
# epoch = 52, batch = 2, losses = [561.1915, 221.9391, 3.2743351]
# epoch = 52, batch = 3, losses = [561.94025, 210.09357, 3.0840678]
# epoch = 52, batch = 4, losses = [539.7358, 234.33952, 3.167491]
# epoch = 52, batch = 5, losses = [548.53174, 241.16916, 3.4125533]
# epoch = 52, batch = 6, losses = [515.02686, 217.18094, 3.140398]
# epoch = 52, batch = 7, losses = [497.9397, 217.94624, 2.8135133]
# epoch = 52, batch = 8, losses = [578.61975, 216.34703, 2.9577944]
# epoch = 52, batch = 9, losses = [488.41547, 209.57472, 2.9145627]
# epoch = 52, batch = 10, losses = [543.563, 199.86182, 3.3079975]
# epoch = 53, batch = 1, losses = [504.86343, 209.30978, 2.9842236]
# epoch = 53, batch = 2, losses = [528.6364, 219.22456, 3.0747]
# epoch = 53, batch = 3, losses = [530.0291, 207.46239, 2.8927882]
# epoch = 53, batch = 4, losses = [508.0959, 231.51822, 2.9714706]
# epoch = 53, batch = 5, losses = [516.3017, 238.33496, 3.2042754]
# epoch = 53, batch = 6, losses = [484.84213, 214.52766, 2.9471507]
# epoch = 53, batch = 7, losses = [469.27655, 215.26346, 2.6379945]
# epoch = 53, batch = 8, losses = [544.5131, 213.73303, 2.7736762]
# epoch = 53, batch = 9, losses = [458.5329, 206.96756, 2.7325494]
# epoch = 53, batch = 10, losses = [511.24606, 197.36284, 3.1067476]
# epoch = 54, batch = 1, losses = [474.09668, 206.74101, 2.7995958]
# epoch = 54, batch = 2, losses = [497.82443, 216.53992, 2.8885012]
# epoch = 54, batch = 3, losses = [499.71024, 204.86176, 2.7146022]
# epoch = 54, batch = 4, losses = [478.18192, 228.72906, 2.7888746]
# epoch = 54, batch = 5, losses = [485.79276, 235.53293, 3.0101082]
# epoch = 54, batch = 6, losses = [456.34274, 211.90683, 2.7670968]
# epoch = 54, batch = 7, losses = [442.1822, 212.61383, 2.4746108]
# epoch = 54, batch = 8, losses = [512.2233, 211.1521, 2.6022992]
# epoch = 54, batch = 9, losses = [430.46982, 204.3946, 2.5631838]
# epoch = 54, batch = 10, losses = [480.7185, 194.89795, 2.9192011]
# epoch = 55, batch = 1, losses = [445.14008, 204.20773, 2.6277685]
# epoch = 55, batch = 2, losses = [468.714, 213.89172, 2.7149384]
# epoch = 55, batch = 3, losses = [470.95868, 202.29794, 2.5487392]
# epoch = 55, batch = 4, losses = [449.9546, 225.97855, 2.6188993]
# epoch = 55, batch = 5, losses = [456.96606, 232.76953, 2.8292158]
# epoch = 55, batch = 6, losses = [429.4628, 209.32422, 2.5994542]
# epoch = 55, batch = 7, losses = [416.60867, 210.0032, 2.322637]
# epoch = 55, batch = 8, losses = [481.70395, 208.60968, 2.4429064]
# epoch = 55, batch = 9, losses = [404.15475, 201.86134, 2.4057193]
# epoch = 55, batch = 10, losses = [451.9323, 192.47205, 2.7445362]
# epoch = 56, batch = 1, losses = [417.9357, 201.71484, 2.4679601]
# epoch = 56, batch = 2, losses = [441.26196, 211.28503, 2.5532622]
# epoch = 56, batch = 3, losses = [443.7475, 199.77562, 2.3944502]
# epoch = 56, batch = 4, losses = [423.37106, 223.27176, 2.4607787]
# epoch = 56, batch = 5, losses = [429.78226, 230.0495, 2.6607883]
# epoch = 56, batch = 6, losses = [404.14618, 206.78409, 2.4434576]
# epoch = 56, batch = 7, losses = [392.50763, 207.43549, 2.1813447]
# epoch = 56, batch = 8, losses = [452.9077, 206.10945, 2.2947216]
# epoch = 56, batch = 9, losses = [379.52335, 199.37119, 2.259379]
# epoch = 56, batch = 10, losses = [424.83875, 190.08838, 2.5819342]
# epoch = 57, batch = 1, losses = [392.42584, 199.26543, 2.3193808]
# epoch = 57, batch = 2, losses = [415.42267, 208.72296, 2.4027007]
# epoch = 57, batch = 3, losses = [418.0467, 197.29758, 2.2509556]
# epoch = 57, batch = 4, losses = [398.3845, 220.61145, 2.3137207]
# epoch = 57, batch = 5, losses = [404.20157, 227.37561, 2.5040045]
# epoch = 57, batch = 6, losses = [380.34448, 204.28894, 2.2983305]
# epoch = 57, batch = 7, losses = [369.8327, 204.91312, 2.0500195]
# epoch = 57, batch = 8, losses = [425.78867, 203.6536, 2.1569824]
# epoch = 57, batch = 9, losses = [356.51093, 196.92621, 2.1233957]
# epoch = 57, batch = 10, losses = [399.3898, 187.7488, 2.4305823]
# epoch = 58, batch = 1, losses = [368.5522, 196.86143, 2.1812701]
# epoch = 58, batch = 2, losses = [391.14694, 206.20743, 2.2625167]
# epoch = 58, batch = 3, losses = [393.82388, 194.8657, 2.1175346]
# epoch = 58, batch = 4, losses = [374.9449, 217.99942, 2.176957]
# epoch = 58, batch = 5, losses = [380.17743, 224.74954, 2.3580616]
# epoch = 58, batch = 6, losses = [358.0079, 201.84003, 2.1633058]
# epoch = 58, batch = 7, losses = [348.53824, 202.43742, 1.9279554]
# epoch = 58, batch = 8, losses = [400.29892, 201.24336, 2.0289521]
# epoch = 58, batch = 9, losses = [335.0532, 194.5275, 1.9970273]
# epoch = 58, batch = 10, losses = [375.53293, 185.45428, 2.289685]
# epoch = 59, batch = 1, losses = [346.253, 194.50381, 2.0528631]
# epoch = 59, batch = 2, losses = [368.3847, 203.73932, 2.131966]
# epoch = 59, batch = 3, losses = [371.0424, 192.48077, 1.993447]
# epoch = 59, batch = 4, losses = [352.99783, 215.43665, 2.0497518]
# epoch = 59, batch = 5, losses = [357.6627, 222.1723, 2.2221866]
# epoch = 59, batch = 6, losses = [337.0905, 199.43831, 2.037676]
# epoch = 59, batch = 7, losses = [328.57806, 200.00916, 1.8144816]
# epoch = 59, batch = 8, losses = [376.38968, 198.87953, 1.9099275]
# epoch = 59, batch = 9, losses = [315.0867, 192.17587, 1.8795812]
# epoch = 59, batch = 10, losses = [353.21536, 183.20555, 2.158501]
# epoch = 60, batch = 1, losses = [325.46848, 192.1932, 1.9334561]
# epoch = 60, batch = 2, losses = [347.0826, 201.31956, 2.0103848]
# epoch = 60, batch = 3, losses = [349.6627, 190.1435, 1.8780262]
# epoch = 60, batch = 4, losses = [332.48868, 212.9238, 1.9314079]
# epoch = 60, batch = 5, losses = [336.607, 219.64449, 2.0956628]
# epoch = 60, batch = 6, losses = [317.53983, 197.08418, 1.9207482]
# epoch = 60, batch = 7, losses = [309.9032, 197.62881, 1.7089697]
# epoch = 60, batch = 8, losses = [354.00867, 196.56252, 1.7992462]
# epoch = 60, batch = 9, losses = [296.54675, 189.87166, 1.7703931]
# epoch = 60, batch = 10, losses = [332.38037, 181.00294, 2.0363283]
# epoch = 61, batch = 1, losses = [306.1308, 189.9301, 1.8223947]
# epoch = 61, batch = 2, losses = [327.1862, 198.94846, 1.8971133]
# epoch = 61, batch = 3, losses = [329.641, 187.85422, 1.7706304]
# epoch = 61, batch = 4, losses = [313.3596, 210.46127, 1.8212748]
# epoch = 61, batch = 5, losses = [316.95615, 217.16652, 1.9778048]
# epoch = 61, batch = 6, losses = [299.3013, 194.77805, 1.8118931]
# epoch = 61, batch = 7, losses = [292.4641, 195.29672, 1.610826]
# epoch = 61, batch = 8, losses = [333.10126, 194.29259, 1.6962831]
# epoch = 61, batch = 9, losses = [279.36636, 187.61528, 1.6688498]
# epoch = 61, batch = 10, losses = [312.9666, 178.84683, 1.9225093]
# epoch = 62, batch = 1, losses = [288.1739, 187.71475, 1.7190505]
# epoch = 62, batch = 2, losses = [308.63852, 196.62636, 1.7915517]
# epoch = 62, batch = 3, losses = [310.93085, 185.61322, 1.6706663]
# epoch = 62, batch = 4, losses = [295.55307, 208.04941, 1.7187508]
# epoch = 62, batch = 5, losses = [298.65286, 214.73868, 1.8679861]
# epoch = 62, batch = 6, losses = [282.31726, 192.52005, 1.710517]
# epoch = 62, batch = 7, losses = [276.2096, 193.01314, 1.5195115]
# epoch = 62, batch = 8, losses = [313.61172, 192.06993, 1.6004698]
# epoch = 62, batch = 9, losses = [263.48032, 185.40668, 1.5743729]
# epoch = 62, batch = 10, losses = [294.91376, 176.73729, 1.8164368]
# epoch = 63, batch = 1, losses = [271.52792, 185.5473, 1.6228511]
# epoch = 63, batch = 2, losses = [291.37906, 194.35352, 1.6931446]
# epoch = 63, batch = 3, losses = [293.48413, 183.42062, 1.577583]
# epoch = 63, batch = 4, losses = [279.00806, 205.68835, 1.6232662]
# epoch = 63, batch = 5, losses = [281.6373, 212.36098, 1.7656071]
# epoch = 63, batch = 6, losses = [266.52658, 190.31012, 1.6160564]
# epoch = 63, batch = 7, losses = [261.08545, 190.77788, 1.4345025]
# epoch = 63, batch = 8, losses = [295.48114, 189.89453, 1.5112648]
# epoch = 63, batch = 9, losses = [248.81972, 183.24606, 1.4864378]
# epoch = 63, batch = 10, losses = [278.15637, 174.67426, 1.7175317]
# epoch = 64, batch = 1, losses = [256.12292, 183.42773, 1.5332602]
# epoch = 64, batch = 2, losses = [275.3482, 192.12994, 1.6013656]
# epoch = 64, batch = 3, losses = [277.2481, 181.27652, 1.4908725]
# epoch = 64, batch = 4, losses = [263.66425, 203.37808, 1.5343039]
# epoch = 64, batch = 5, losses = [265.8475, 210.03351, 1.670137]
# epoch = 64, batch = 6, losses = [251.86775, 188.14836, 1.5280179]
# epoch = 64, batch = 7, losses = [247.03891, 188.59088, 1.3553348]
# epoch = 64, batch = 8, losses = [278.65024, 187.76633, 1.4281809]
# epoch = 64, batch = 9, losses = [235.31718, 181.13329, 1.4045571]
# epoch = 64, batch = 10, losses = [262.62744, 172.6578, 1.6252866]
# epoch = 65, batch = 1, losses = [241.88629, 181.35611, 1.4497918]
# epoch = 65, batch = 2, losses = [260.48312, 189.95546, 1.5157313]
# epoch = 65, batch = 3, losses = [262.17038, 179.18057, 1.4100561]
# epoch = 65, batch = 4, losses = [249.45839, 201.11815, 1.4513673]
# epoch = 65, batch = 5, losses = [251.21774, 207.75587, 1.5810559]
# epoch = 65, batch = 6, losses = [238.27516, 186.03409, 1.4459084]
# epoch = 65, batch = 7, losses = [234.01347, 186.45189, 1.2815698]
# epoch = 65, batch = 8, losses = [263.05655, 185.68503, 1.3507583]
# epoch = 65, batch = 9, losses = [222.90294, 179.06793, 1.3282673]
# epoch = 65, batch = 10, losses = [248.2583, 170.68748, 1.539198]
# epoch = 66, batch = 1, losses = [228.74648, 179.33191, 1.3719778]
# epoch = 66, batch = 2, losses = [246.72159, 187.82983, 1.4357904]
# epoch = 66, batch = 3, losses = [248.19437, 177.13232, 1.334686]
# epoch = 66, batch = 4, losses = [236.3269, 198.90817, 1.3740078]
# epoch = 66, batch = 5, losses = [237.68193, 205.52756, 1.4978913]
# epoch = 66, batch = 6, losses = [225.68411, 183.96701, 1.369296]
# epoch = 66, batch = 7, losses = [221.95442, 184.36032, 1.2127972]
# epoch = 66, batch = 8, losses = [248.6397, 183.65013, 1.278568]
# epoch = 66, batch = 9, losses = [211.50696, 177.0497, 1.2571484]
# epoch = 66, batch = 10, losses = [234.97737, 168.76294, 1.4588143]
# epoch = 67, batch = 1, losses = [216.63094, 177.35477, 1.2993916]
# epoch = 67, batch = 2, losses = [234.0014, 185.7525, 1.3611203]
# epoch = 67, batch = 3, losses = [235.26443, 175.1314, 1.2643628]
# epoch = 67, batch = 4, losses = [224.20622, 196.74771, 1.3018148]
# epoch = 67, batch = 5, losses = [225.16968, 203.34795, 1.4202107]
# epoch = 67, batch = 6, losses = [214.02762, 181.94641, 1.2977668]
# epoch = 67, batch = 7, losses = [210.8074, 182.31554, 1.1486411]
# epoch = 67, batch = 8, losses = [235.33614, 181.66107, 1.2112124]
# epoch = 67, batch = 9, losses = [201.0585, 175.07805, 1.190813]
# epoch = 67, batch = 10, losses = [222.71266, 166.88371, 1.3837149]
# epoch = 68, batch = 1, losses = [205.46745, 175.42426, 1.2316489]
# epoch = 68, batch = 2, losses = [222.2605, 183.723, 1.2913408]
# epoch = 68, batch = 3, losses = [223.32367, 173.17703, 1.1987051]
# epoch = 68, batch = 4, losses = [213.0301, 194.6358, 1.2344002]
# epoch = 68, batch = 5, losses = [213.61134, 201.21634, 1.3476119]
# epoch = 68, batch = 6, losses = [203.24022, 179.97159, 1.2309495]
# epoch = 68, batch = 7, losses = [200.51878, 180.31705, 1.0887625]
# epoch = 68, batch = 8, losses = [223.08365, 179.71747, 1.1483457]
# epoch = 68, batch = 9, losses = [191.4869, 173.1525, 1.1289062]
# epoch = 68, batch = 10, losses = [211.39182, 165.04941, 1.313522]
# epoch = 69, batch = 1, losses = [195.18903, 173.53986, 1.1683897]
# epoch = 69, batch = 2, losses = [211.44058, 181.7407, 1.2260934]
# epoch = 69, batch = 3, losses = [212.31224, 171.26859, 1.1373674]
# epoch = 69, batch = 4, losses = [202.73262, 192.57175, 1.171407]
# epoch = 69, batch = 5, losses = [202.93504, 199.13176, 1.2797185]
# epoch = 69, batch = 6, losses = [193.26056, 178.04175, 1.1684936]
# epoch = 69, batch = 7, losses = [191.03545, 178.36398, 1.0328367]
# epoch = 69, batch = 8, losses = [211.81819, 177.81859, 1.0896214]
# epoch = 69, batch = 9, losses = [182.71815, 171.27252, 1.0710936]
# epoch = 69, batch = 10, losses = [200.94225, 163.25926, 1.2478697]
# epoch = 70, batch = 1, losses = [185.72997, 171.70074, 1.1092739]
# epoch = 70, batch = 2, losses = [201.48463, 179.8047, 1.1650409]
# epoch = 70, batch = 3, losses = [202.17145, 169.40515, 1.0800315]
# epoch = 70, batch = 4, losses = [193.24667, 190.5545, 1.1125115]
# epoch = 70, batch = 5, losses = [193.07092, 197.09335, 1.2161934]
# epoch = 70, batch = 6, losses = [184.02869, 176.15604, 1.110083]
# epoch = 70, batch = 7, losses = [182.30698, 176.45567, 0.98057383]
# epoch = 70, batch = 8, losses = [201.47528, 175.96382, 1.0347368]
# epoch = 70, batch = 9, losses = [174.67915, 169.43732, 1.0170676]
# epoch = 70, batch = 10, losses = [191.29256, 161.5127, 1.186425]
# epoch = 71, batch = 1, losses = [177.03021, 169.9063, 1.0539979]
# epoch = 71, batch = 2, losses = [192.33833, 177.91429, 1.1078888]
# epoch = 71, batch = 3, losses = [192.83888, 167.58566, 1.0263937]
# epoch = 71, batch = 4, losses = [184.50356, 188.58293, 1.0574051]
# epoch = 71, batch = 5, losses = [183.95097, 195.10011, 1.1567148]
# epoch = 71, batch = 6, losses = [175.49135, 174.31358, 1.0554162]
# epoch = 71, batch = 7, losses = [174.28188, 174.59137, 0.931702]
# epoch = 71, batch = 8, losses = [191.98804, 174.15259, 0.98340636]
# epoch = 71, batch = 9, losses = [167.29515, 167.64647, 0.9665535]
# epoch = 71, batch = 10, losses = [182.37643, 159.8091, 1.1288867]
# epoch = 72, batch = 1, losses = [169.03716, 168.1556, 1.0022737]
# epoch = 72, batch = 2, losses = [183.94933, 176.06825, 1.0543404]
# epoch = 72, batch = 3, losses = [184.25027, 165.80911, 0.97618455]
# epoch = 72, batch = 4, losses = [176.43637, 186.65602, 1.0058147]
# epoch = 72, batch = 5, losses = [175.51236, 193.15092, 1.1009885]
# epoch = 72, batch = 6, losses = [167.60297, 172.51349, 1.0042241]
# epoch = 72, batch = 7, losses = [166.91034, 172.77039, 0.88597184]
# epoch = 72, batch = 8, losses = [183.2862, 172.3842, 0.93536913]
# epoch = 72, batch = 9, losses = [160.49411, 165.89911, 0.9192859]
# epoch = 72, batch = 10, losses = [174.13301, 158.1476, 1.0749683]
# epoch = 73, batch = 1, losses = [161.7046, 166.44774, 0.9538411]
# epoch = 73, batch = 2, losses = [176.2664, 174.26562, 1.0041442]
# epoch = 73, batch = 3, losses = [176.33833, 164.07437, 0.92915183]
# epoch = 73, batch = 4, losses = [168.97948, 184.77258, 0.9574825]
# epoch = 73, batch = 5, losses = [167.70059, 191.24487, 1.0487475]
# epoch = 73, batch = 6, losses = [160.32616, 170.75508, 0.956257]
# epoch = 73, batch = 7, losses = [160.13997, 170.99203, 0.84315383]
# epoch = 73, batch = 8, losses = [175.2975, 170.65825, 0.8903903]
# epoch = 73, batch = 9, losses = [154.20804, 164.1947, 0.8750305]
# epoch = 73, batch = 10, losses = [166.51094, 156.52747, 1.0244111]
# epoch = 74, batch = 1, losses = [154.99199, 164.78172, 0.90845937]
# epoch = 74, batch = 2, losses = [169.23619, 172.50526, 0.95705837]
# epoch = 74, batch = 3, losses = [169.03569, 162.38036, 0.88506883]
# epoch = 74, batch = 4, losses = [162.07343, 182.93155, 0.91217476]
# epoch = 74, batch = 5, losses = [160.47154, 189.38116, 0.9997477]
# epoch = 74, batch = 6, losses = [153.62852, 169.03775, 0.9112842]
# ...
# epoch = 977, batch = 5, losses = [31.53097, 91.13951, 0.012862653]
# epoch = 977, batch = 6, losses = [52.671986, 84.9059, 0.011204289]
# epoch = 977, batch = 7, losses = [83.75006, 83.12033, 0.01011291]
# epoch = 977, batch = 8, losses = [86.67928, 85.1274, 0.0100076385]
# epoch = 977, batch = 9, losses = [68.32456, 82.95692, 0.0105299605]
# epoch = 977, batch = 10, losses = [43.215984, 81.15477, 0.012332943]
# epoch = 978, batch = 1, losses = [12.093992, 86.77422, 0.011122938]
# epoch = 978, batch = 2, losses = [15.169461, 84.03728, 0.012103452]
# epoch = 978, batch = 3, losses = [40.369373, 81.410835, 0.01077057]
# epoch = 978, batch = 4, losses = [66.23099, 88.823845, 0.011746451]
# epoch = 978, batch = 5, losses = [71.1821, 90.56709, 0.012274177]
# epoch = 978, batch = 6, losses = [74.340515, 85.55507, 0.011597389]
# epoch = 978, batch = 7, losses = [64.599754, 82.43424, 0.00981648]
# epoch = 978, batch = 8, losses = [38.589108, 85.71229, 0.011154446]
# epoch = 978, batch = 9, losses = [9.07176, 82.7546, 0.010709179]
# epoch = 978, batch = 10, losses = [12.977913, 81.48146, 0.012847338]
# epoch = 979, batch = 1, losses = [17.382599, 86.74658, 0.01144852]
# epoch = 979, batch = 2, losses = [25.234259, 83.54256, 0.012234224]
# epoch = 979, batch = 3, losses = [25.1908, 81.548355, 0.011307498]
# epoch = 979, batch = 4, losses = [17.64, 88.322815, 0.01127402]
# epoch = 979, batch = 5, losses = [10.003633, 91.03209, 0.012861933]
# epoch = 979, batch = 6, losses = [6.982627, 85.21547, 0.011852756]
# epoch = 979, batch = 7, losses = [7.9743605, 82.84267, 0.010395178]
# epoch = 979, batch = 8, losses = [7.98317, 85.78498, 0.011047092]
# epoch = 979, batch = 9, losses = [9.05626, 82.90783, 0.010706813]
# epoch = 979, batch = 10, losses = [7.4864073, 81.58357, 0.0131247025]
# epoch = 980, batch = 1, losses = [8.919314, 86.574844, 0.011379031]
# epoch = 980, batch = 2, losses = [6.8535924, 83.82523, 0.012326244]
# epoch = 980, batch = 3, losses = [8.200845, 81.5469, 0.011168423]
# epoch = 980, batch = 4, losses = [6.1107726, 88.498726, 0.011648453]
# epoch = 980, batch = 5, losses = [7.008218, 90.99288, 0.01324066]
# epoch = 980, batch = 6, losses = [7.713638, 85.127014, 0.011986511]
# epoch = 980, batch = 7, losses = [6.52461, 82.78572, 0.010388997]
# epoch = 980, batch = 8, losses = [7.648453, 85.4624, 0.010868995]
# epoch = 980, batch = 9, losses = [5.5529375, 82.66463, 0.010721785]
# epoch = 980, batch = 10, losses = [7.2005186, 81.32043, 0.013048771]
# epoch = 981, batch = 1, losses = [6.4036727, 86.54934, 0.011353097]
# epoch = 981, batch = 2, losses = [7.052438, 83.81918, 0.012307271]
# epoch = 981, batch = 3, losses = [7.3014684, 81.570854, 0.011289585]
# epoch = 981, batch = 4, losses = [6.173628, 88.51817, 0.011768275]
# epoch = 981, batch = 5, losses = [6.2930474, 90.9886, 0.013097477]
# epoch = 981, batch = 6, losses = [5.9047847, 85.23305, 0.01177158]
# epoch = 981, batch = 7, losses = [6.452587, 82.741936, 0.01019476]
# epoch = 981, batch = 8, losses = [6.8366866, 85.51997, 0.010915152]
# epoch = 981, batch = 9, losses = [6.331702, 82.67172, 0.0107080685]
# epoch = 981, batch = 10, losses = [5.799278, 81.406395, 0.01302775]
# epoch = 982, batch = 1, losses = [6.521021, 86.56947, 0.011323803]
# epoch = 982, batch = 2, losses = [6.442878, 83.72633, 0.012295786]
# epoch = 982, batch = 3, losses = [7.9765763, 81.48975, 0.011256532]
# epoch = 982, batch = 4, losses = [6.3377533, 88.379425, 0.011578537]
# epoch = 982, batch = 5, losses = [6.4536405, 90.92678, 0.012949395]
# epoch = 982, batch = 6, losses = [5.752921, 85.164215, 0.011686769]
# epoch = 982, batch = 7, losses = [5.5403857, 82.774185, 0.010238029]
# epoch = 982, batch = 8, losses = [5.911128, 85.54503, 0.010892279]
# epoch = 982, batch = 9, losses = [5.481936, 82.76555, 0.01068376]
# epoch = 982, batch = 10, losses = [5.8482814, 81.46864, 0.01295765]
# epoch = 983, batch = 1, losses = [6.680744, 86.55933, 0.011238457]
# epoch = 983, batch = 2, losses = [6.314678, 83.7524, 0.01223181]
# epoch = 983, batch = 3, losses = [7.1395392, 81.444016, 0.011068209]
# epoch = 983, batch = 4, losses = [5.3471007, 88.42172, 0.011523082]
# epoch = 983, batch = 5, losses = [5.9010305, 90.86401, 0.012872445]
# epoch = 983, batch = 6, losses = [5.502818, 85.16801, 0.011691616]
# epoch = 983, batch = 7, losses = [5.595207, 82.7591, 0.010204092]
# epoch = 983, batch = 8, losses = [5.9501324, 85.50086, 0.010787521]
# epoch = 983, batch = 9, losses = [5.2844415, 82.76231, 0.010603175]
# epoch = 983, batch = 10, losses = [5.451278, 81.41864, 0.012807143]
# epoch = 984, batch = 1, losses = [6.2602687, 86.59047, 0.01118524]
# epoch = 984, batch = 2, losses = [6.0049186, 83.75314, 0.012145914]
# epoch = 984, batch = 3, losses = [6.9411135, 81.48961, 0.01102713]
# epoch = 984, batch = 4, losses = [5.3532352, 88.44496, 0.011477462]
# epoch = 984, batch = 5, losses = [6.044388, 90.850136, 0.012779944]
# epoch = 984, batch = 6, losses = [5.6018634, 85.18662, 0.01161031]
# epoch = 984, batch = 7, losses = [5.758441, 82.711945, 0.010088902]
# epoch = 984, batch = 8, losses = [6.0130887, 85.50172, 0.010727125]
# epoch = 984, batch = 9, losses = [5.3167043, 82.72877, 0.0105203595]
# epoch = 984, batch = 10, losses = [5.4123697, 81.423096, 0.012754842]
# epoch = 985, batch = 1, losses = [6.253772, 86.58143, 0.011133361]
# epoch = 985, batch = 2, losses = [6.0674024, 83.71152, 0.012075617]
# epoch = 985, batch = 3, losses = [6.989319, 81.48568, 0.010986878]
# epoch = 985, batch = 4, losses = [5.31262, 88.38146, 0.011375801]
# epoch = 985, batch = 5, losses = [5.901741, 90.83446, 0.012714249]
# epoch = 985, batch = 6, losses = [5.4700265, 85.149506, 0.011520585]
# epoch = 985, batch = 7, losses = [5.5290136, 82.722916, 0.010044715]
# epoch = 985, batch = 8, losses = [5.871083, 85.490654, 0.010655872]
# epoch = 985, batch = 9, losses = [5.263424, 82.73553, 0.0104715815]
# epoch = 985, batch = 10, losses = [5.442848, 81.42921, 0.012691511]
# epoch = 986, batch = 1, losses = [6.2890625, 86.5685, 0.011049258]
# epoch = 986, batch = 2, losses = [6.0322714, 83.71049, 0.011999094]
# epoch = 986, batch = 3, losses = [6.962207, 81.4569, 0.010891863]
# epoch = 986, batch = 4, losses = [5.3069477, 88.37631, 0.011333832]
# epoch = 986, batch = 5, losses = [5.964405, 90.78897, 0.012635077]
# epoch = 986, batch = 6, losses = [5.5387363, 85.15548, 0.011472772]
# epoch = 986, batch = 7, losses = [5.658847, 82.69222, 0.0099834595]
# epoch = 986, batch = 8, losses = [5.9764104, 85.47917, 0.010613741]
# epoch = 986, batch = 9, losses = [5.332503, 82.71614, 0.010407022]
# epoch = 986, batch = 10, losses = [5.434815, 81.42589, 0.012611437]
# epoch = 987, batch = 1, losses = [6.2611217, 86.56848, 0.010989984]
# epoch = 987, batch = 2, losses = [6.025394, 83.68539, 0.011933807]
# epoch = 987, batch = 3, losses = [6.929329, 81.46495, 0.010855305]
# epoch = 987, batch = 4, losses = [5.268962, 88.34889, 0.011259959]
# epoch = 987, batch = 5, losses = [5.8857965, 90.78861, 0.012581552]
# epoch = 987, batch = 6, losses = [5.47856, 85.131714, 0.01140128]
# epoch = 987, batch = 7, losses = [5.5327177, 82.69761, 0.009942793]
# epoch = 987, batch = 8, losses = [5.8746414, 85.45738, 0.010538789]
# epoch = 987, batch = 9, losses = [5.240881, 82.71869, 0.010357827]
# epoch = 987, batch = 10, losses = [5.408626, 81.418076, 0.012546166]
# epoch = 988, batch = 1, losses = [6.259967, 86.564606, 0.010938888]
# epoch = 988, batch = 2, losses = [6.0119085, 83.68359, 0.01188252]
# epoch = 988, batch = 3, losses = [6.9546933, 81.44821, 0.010789286]
# epoch = 988, batch = 4, losses = [5.300619, 88.347595, 0.011221505]
# epoch = 988, batch = 5, losses = [5.983782, 90.74795, 0.012502674]
# epoch = 988, batch = 6, losses = [5.5770617, 85.13832, 0.0113562625]
# epoch = 988, batch = 7, losses = [5.7448463, 82.66292, 0.009878864]
# epoch = 988, batch = 8, losses = [6.069825, 85.461815, 0.010512564]
# epoch = 988, batch = 9, losses = [5.4443455, 82.69841, 0.01030122]
# epoch = 988, batch = 10, losses = [5.524925, 81.4276, 0.012500592]
# epoch = 989, batch = 1, losses = [6.3114963, 86.55236, 0.010882345]
# epoch = 989, batch = 2, losses = [6.020365, 83.66173, 0.011825447]
# epoch = 989, batch = 3, losses = [6.9287906, 81.44477, 0.010748062]
# epoch = 989, batch = 4, losses = [5.2535777, 88.318565, 0.011158256]
# epoch = 989, batch = 5, losses = [5.8838825, 90.74867, 0.01246878]
# epoch = 989, batch = 6, losses = [5.4913054, 85.11203, 0.011300835]
# epoch = 989, batch = 7, losses = [5.537676, 82.67874, 0.00985788]
# epoch = 989, batch = 8, losses = [5.8923664, 85.431175, 0.010441033]
# epoch = 989, batch = 9, losses = [5.236652, 82.70668, 0.01026954]
# epoch = 989, batch = 10, losses = [5.40584, 81.40469, 0.012428018]
# epoch = 990, batch = 1, losses = [6.245769, 86.559746, 0.010846666]
# epoch = 990, batch = 2, losses = [6.0078545, 83.658104, 0.011778548]
# epoch = 990, batch = 3, losses = [6.9520893, 81.43577, 0.010699288]
# epoch = 990, batch = 4, losses = [5.31316, 88.3194, 0.011127663]
# epoch = 990, batch = 5, losses = [6.0343575, 90.70881, 0.012391642]
# epoch = 990, batch = 6, losses = [5.6839933, 85.12436, 0.0112628825]
# epoch = 990, batch = 7, losses = [5.9828787, 82.63135, 0.009789697]
# epoch = 990, batch = 8, losses = [6.3739853, 85.450455, 0.010437221]
# epoch = 990, batch = 9, losses = [5.837498, 82.67272, 0.010207762]
# epoch = 990, batch = 10, losses = [5.9082413, 81.432556, 0.012414543]
# epoch = 991, batch = 1, losses = [6.576347, 86.52595, 0.010779943]
# epoch = 991, batch = 2, losses = [6.1138144, 83.64342, 0.011735089]
# epoch = 991, batch = 3, losses = [6.977057, 81.41913, 0.0106534595]
# epoch = 991, batch = 4, losses = [5.251611, 88.29804, 0.011082289]
# epoch = 991, batch = 5, losses = [5.8793983, 90.7144, 0.012377102]
# epoch = 991, batch = 6, losses = [5.4955206, 85.097, 0.011221331]
# epoch = 991, batch = 7, losses = [5.538166, 82.65629, 0.009784344]
# epoch = 991, batch = 8, losses = [5.9127564, 85.40407, 0.0103565985]
# epoch = 991, batch = 9, losses = [5.2537146, 82.68978, 0.010187691]
# epoch = 991, batch = 10, losses = [5.435412, 81.38851, 0.012322655]
# epoch = 992, batch = 1, losses = [6.2627597, 86.55552, 0.010774136]
# epoch = 992, batch = 2, losses = [6.0272665, 83.63269, 0.011693804]
# epoch = 992, batch = 3, losses = [6.9302783, 81.43135, 0.01063403]
# epoch = 992, batch = 4, losses = [5.2473965, 88.28835, 0.011038902]
# epoch = 992, batch = 5, losses = [5.9360175, 90.686226, 0.012304346]
# epoch = 992, batch = 6, losses = [5.562188, 85.09689, 0.011171779]
# epoch = 992, batch = 7, losses = [5.7759676, 82.61878, 0.009722152]
# epoch = 992, batch = 8, losses = [6.188343, 85.425255, 0.010355388]
# epoch = 992, batch = 9, losses = [5.72354, 82.65953, 0.010141957]
# epoch = 992, batch = 10, losses = [5.930052, 81.42079, 0.012332203]
# epoch = 993, batch = 1, losses = [6.738244, 86.50824, 0.010698557]
# epoch = 993, batch = 2, losses = [6.3315663, 83.63155, 0.011656776]
# epoch = 993, batch = 3, losses = [7.3237395, 81.3852, 0.010560931]
# epoch = 993, batch = 4, losses = [5.614813, 88.293884, 0.011030044]
# epoch = 993, batch = 5, losses = [6.3193855, 90.657845, 0.012267424]
# epoch = 993, batch = 6, losses = [6.026618, 85.114075, 0.0111713195]
# epoch = 993, batch = 7, losses = [6.57585, 82.58668, 0.009685727]
# epoch = 993, batch = 8, losses = [7.1696258, 85.43207, 0.010341833]
# epoch = 993, batch = 9, losses = [6.909576, 82.62697, 0.010070544]
# epoch = 993, batch = 10, losses = [7.130303, 81.436165, 0.012297234]
# epoch = 994, batch = 1, losses = [7.543129, 86.48101, 0.010645219]
# epoch = 994, batch = 2, losses = [6.676187, 83.63213, 0.011639544]
# epoch = 994, batch = 3, losses = [7.4840984, 81.38291, 0.01054081]
# epoch = 994, batch = 4, losses = [5.639793, 88.29929, 0.011017947]
# epoch = 994, batch = 5, losses = [6.236767, 90.65926, 0.01225432]
# epoch = 994, batch = 6, losses = [5.794539, 85.09681, 0.011139578]
# epoch = 994, batch = 7, losses = [6.0869946, 82.58345, 0.009656344]
# epoch = 994, batch = 8, losses = [6.539849, 85.40048, 0.010276727]
# epoch = 994, batch = 9, losses = [6.055821, 82.62703, 0.010040134]
# epoch = 994, batch = 10, losses = [6.1765027, 81.41295, 0.012244283]
# epoch = 995, batch = 1, losses = [6.8440156, 86.49785, 0.010642767]
# epoch = 995, batch = 2, losses = [6.318987, 83.62938, 0.01161546]
# epoch = 995, batch = 3, losses = [7.290315, 81.389, 0.010523832]
# epoch = 995, batch = 4, losses = [5.57549, 88.28335, 0.010980585]
# epoch = 995, batch = 5, losses = [6.3062873, 90.63163, 0.0122014275]
# epoch = 995, batch = 6, losses = [6.025962, 85.08449, 0.011098402]
# epoch = 995, batch = 7, losses = [6.702742, 82.55433, 0.009613571]
# epoch = 995, batch = 8, losses = [7.4808764, 85.40785, 0.010276543]
# epoch = 995, batch = 9, losses = [7.618067, 82.59531, 0.010009543]
# epoch = 995, batch = 10, losses = [8.385536, 81.434555, 0.012256084]
# epoch = 996, batch = 1, losses = [9.083586, 86.444435, 0.010565792]
# epoch = 996, batch = 2, losses = [8.408463, 83.64262, 0.011592893]
# epoch = 996, batch = 3, losses = [10.1365595, 81.32488, 0.010443172]
# epoch = 996, batch = 4, losses = [9.008961, 88.3344, 0.011024954]
# epoch = 996, batch = 5, losses = [10.848874, 90.56793, 0.012135445]
# epoch = 996, batch = 6, losses = [13.315837, 85.17462, 0.011161154]
# epoch = 996, batch = 7, losses = [21.768343, 82.41775, 0.009510542]
# epoch = 996, batch = 8, losses = [29.560852, 85.537834, 0.010392818]
# epoch = 996, batch = 9, losses = [39.621006, 82.44523, 0.009824659]
# epoch = 996, batch = 10, losses = [49.617435, 81.61661, 0.012424973]
# epoch = 997, batch = 1, losses = [43.370586, 86.22967, 0.010373144]
# epoch = 997, batch = 2, losses = [33.306572, 83.74739, 0.01170462]
# epoch = 997, batch = 3, losses = [33.29551, 81.196144, 0.010367905]
# epoch = 997, batch = 4, losses = [27.784576, 88.497856, 0.011286995]
# epoch = 997, batch = 5, losses = [25.421173, 90.538445, 0.012252519]
# epoch = 997, batch = 6, losses = [25.010668, 85.25607, 0.011354869]
# epoch = 997, batch = 7, losses = [33.54623, 82.336, 0.009529804]
# epoch = 997, batch = 8, losses = [36.660397, 85.50023, 0.010421365]
# epoch = 997, batch = 9, losses = [35.36768, 82.42156, 0.009817881]
# epoch = 997, batch = 10, losses = [29.181585, 81.54647, 0.012394186]
# epoch = 998, batch = 1, losses = [15.818493, 86.37852, 0.010653261]
# epoch = 998, batch = 2, losses = [7.2835197, 83.65814, 0.011810934]
# epoch = 998, batch = 3, losses = [8.084902, 81.47574, 0.010760939]
# epoch = 998, batch = 4, losses = [10.980837, 88.24307, 0.011066086]
# epoch = 998, batch = 5, losses = [17.25768, 90.862045, 0.012617355]
# epoch = 998, batch = 6, losses = [28.096937, 84.82669, 0.01112123]
# epoch = 998, batch = 7, losses = [46.530655, 82.85504, 0.009954866]
# epoch = 998, batch = 8, losses = [55.807327, 85.03414, 0.01002514]
# epoch = 998, batch = 9, losses = [55.65835, 82.79824, 0.010445567]
# epoch = 998, batch = 10, losses = [48.379524, 81.03469, 0.012177007]
# epoch = 999, batch = 1, losses = [22.921278, 86.709045, 0.01107994]
# epoch = 999, batch = 2, losses = [9.612539, 83.69914, 0.011855089]
# epoch = 999, batch = 3, losses = [11.425713, 81.34864, 0.010719784]
# epoch = 999, batch = 4, losses = [23.547808, 88.43983, 0.011332886]
# epoch = 999, batch = 5, losses = [40.307014, 90.41122, 0.012108963]
# epoch = 999, batch = 6, losses = [62.030766, 85.33367, 0.011430565]
# epoch = 999, batch = 7, losses = [89.31917, 82.21408, 0.009620808]
# epoch = 999, batch = 8, losses = [85.34775, 85.72789, 0.011089404]
# epoch = 999, batch = 9, losses = [57.066055, 82.43692, 0.010328977]
# epoch = 999, batch = 10, losses = [28.964993, 81.562256, 0.01288501]
# epoch = 1000, batch = 1, losses = [7.7562065, 86.389015, 0.010981356]
# epoch = 1000, batch = 2, losses = [18.507404, 83.33894, 0.01185034]
# epoch = 1000, batch = 3, losses = [45.213757, 81.4606, 0.011094564]
# epoch = 1000, batch = 4, losses = [59.094112, 87.95914, 0.010994402]
# epoch = 1000, batch = 5, losses = [53.408978, 91.10487, 0.013115499]
# epoch = 1000, batch = 6, losses = [45.443504, 84.84816, 0.011616215]
# epoch = 1000, batch = 7, losses = [30.193367, 82.94545, 0.010430624]
# epoch = 1000, batch = 8, losses = [15.530641, 85.388405, 0.010617619]
# epoch = 1000, batch = 9, losses = [5.490721, 82.61971, 0.010518536]
# epoch = 1000, batch = 10, losses = [14.766993, 81.31706, 0.012928022]

# %%
# integral check
class Sol_(tf.keras.models.Model):
   def __init__(self):
       super().__init__(dtype=f.dtype)
   def call(self, t, r):
       return r*tf.exp(-f(t, r))
P_ = Sol_()
#"""
print('integral 1: ', quad.monte_carlo(P_, [space_r], time=time_[0]))
print('integral 2: ', quad.monte_carlo(P_, [space_r], time=time_[1]))
#"""
# Out:
# integral 1:  tf.Tensor(0.49817097, shape=(), dtype=float32)
# integral 2:  tf.Tensor(0.83261657, shape=(), dtype=float32)
